# %% [markdown]
# # Matplotlib I

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.DataFrame(np.random.normal(0,.03,size=60))

# %%
plt.plot(df)

# %%
df[1] = df.cumsum()
df.head()
# Out:
#           0         1
# 0 -0.013119 -0.013119
# 1 -0.022687 -0.035807
# 2  0.010892 -0.024915
# 3 -0.023846 -0.048761
# 4  0.020285 -0.028476

# %%
df.plot()

# %%
x = np.random.standard_normal(10000)

# %%
plt.hist(x, bins=50, edgecolor='black')
# Out:
# (array([  1.,   1.,   2.,   2.,   7.,   7.,  11.,  18.,  25.,  32.,  63.,
#          76.,  92., 127., 151., 190., 249., 284., 348., 387., 484., 499.,
#         505., 524., 527., 582., 571., 581., 503., 470., 452., 411., 349.,
#         312., 278., 221., 163., 142.,  92.,  76.,  50.,  41.,  36.,  19.,
#          16.,  10.,   2.,   7.,   1.,   3.]),
#  array([-3.75278517, -3.60647638, -3.46016759, -3.3138588 , -3.16755   ,
#         -3.02124121, -2.87493242, -2.72862363, -2.58231484, -2.43600605,
#         -2.28969726, -2.14338847, -1.99707967, -1.85077088, -1.70446209,
#         -1.5581533 , -1.41184451, -1.26553572, -1.11922693, -0.97291814,
#         -0.82660935, -0.68030055, -0.53399176, -0.38768297, -0.24137418,
#         -0.09506539,  0.0512434 ,  0.19755219,  0.34386098,  0.49016978,
#          0.63647857,  0.78278736,  0.92909615,  1.07540494,  1.22171373,
#          1.36802252,  1.51433131,  1.6606401 ,  1.8069489 ,  1.95325769,
#          2.09956648,  2.24587527,  2.39218406,  2.53849285,  2.68480164,
#          2.83111043,  2.97741923,  3.12372802,  3.27003681,  3.4163456 ,
#          3.56265439]),
#  <a list of 50 Patch objects>)

# %%
df = pd.DataFrame({'A':np.random.normal(size=50), 'B':np.random.normal(size=50)})

# %%
plt.scatter(df['A'], df['B'])
